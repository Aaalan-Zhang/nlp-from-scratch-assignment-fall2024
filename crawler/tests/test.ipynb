# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_page_text(url):
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad responses
        # Parse the page content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Extract and return the text from the page
        return soup.get_text(separator='\n', strip=True)
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

def crawl_urls(url_list):
    results = {}
    for url in url_list:
        print(f"Fetching: {url}")
        text = fetch_page_text(url)
        if text:
            results[url] = text
    return results

def save_crawled_data(crawled_data, urls):
    # Iterate over each URL and its corresponding text
    for index, url in enumerate(urls):
        # Fetch the text corresponding to the URL from the crawled_data dictionary
        text = crawled_data.get(url, "")

        # Remove all newline characters from the text
        cleaned_text = text.replace('\n', ' ')

        # Define the file name with the index from the URLs list
        output_file = f"/Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/{index}.txt"

        # Save the cleaned text to the file
        with open(output_file, 'w', encoding='utf-8') as file:
            file.write(cleaned_text)

        print(f"Saved content from URL {url} to {output_file}")

if __name__ == "__main__":
    file_path = '/Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/raw/raw_csv_data/data_source.csv'
    data = pd.read_csv(file_path)

    # Extract non-empty URLs from the 'Source URL' column
    urls = data[data['Select'] == 'Webpage']['Source URL'].dropna().unique()
    # Start crawling the URLs
    crawled_data = crawl_urls(urls)
    
    # Print or process the results
    save_crawled_data(crawled_data, urls)
    print("Crawling complete!")
# Out:
# Fetching: https://en.wikipedia.org/wiki/Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/History_of_Pittsburgh
# Fetching: https://pittsburghpa.gov/pittsburgh/pgh-about
# Error fetching https://pittsburghpa.gov/pittsburgh/pgh-about: HTTPSConnectionPool(host='pittsburghpa.gov', port=443): Max retries exceeded with url: /pittsburgh/pgh-about (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1123)')))
# Fetching: https://www.britannica.com/technology/steel/Testing-of-properties
# Fetching: https://pittsburghpa.gov/events/index.html
# Error fetching https://pittsburghpa.gov/events/index.html: HTTPSConnectionPool(host='pittsburghpa.gov', port=443): Max retries exceeded with url: /events/index.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1123)')))
# Fetching: https://www.visitpittsburgh.com/blog/move-in-day-pittsburgh-college-guide/
# Fetching: https://pittsburghpa.gov/mayor/pghmayors
# Error fetching https://pittsburghpa.gov/mayor/pghmayors: HTTPSConnectionPool(host='pittsburghpa.gov', port=443): Max retries exceeded with url: /mayor/pghmayors (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1123)')))
# Fetching: https://en.wikipedia.org/wiki/Economy_of_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/Greater_Pittsburgh#
# Fetching: https://en.wikipedia.org/wiki/Government_of_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/Transportation_in_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/Timeline_of_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/List_of_people_from_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/List_of_corporations_in_Pittsburgh
# Fetching: https://pittsburghpa.gov/pittsburgh/pgh-sports
# Error fetching https://pittsburghpa.gov/pittsburgh/pgh-sports: HTTPSConnectionPool(host='pittsburghpa.gov', port=443): Max retries exceeded with url: /pittsburgh/pgh-sports (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1123)')))
# Fetching: https://pittsburghpa.gov/pittsburgh/cultural-activities
# Error fetching https://pittsburghpa.gov/pittsburgh/cultural-activities: HTTPSConnectionPool(host='pittsburghpa.gov', port=443): Max retries exceeded with url: /pittsburgh/cultural-activities (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:
://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/pittsburgh-riverhounds/
# Fetching: https://www.visitpittsburgh.com/blog/steelers-hall-of-honor-museum/
# Fetching: https://www.visitpittsburgh.com/blog/guide-to-acrisure-stadium-for-steelers-fans/
# Fetching: https://www.visitpittsburgh.com/blog/what-to-eat-at-pnc-park/
# Fetching: https://www.visitpittsburgh.com/blog/ppg-paints-arena-penguins-guide/
# Fetching: https://www.steelers.com/
# Fetching: https://www.steelers.com/schedule/
# Fetching: https://en.wikipedia.org/wiki/Myron_Cope
# Fetching: https://www.dkpittsburghsports.com/
# Fetching: https://en.wikipedia.org/wiki/Sports_in_Pittsburgh
# Fetching: https://www.nytimes.com/athletic/location/pittsburgh/
# Fetching: https://athletics.cmu.edu/landing/index
# Error fetching https://athletics.cmu.edu/landing/index: 403 Client Error: Forbidden for url: https://athletics.cmu.edu/landing/index
# Fetching: https://athletics.cmu.edu/sports/mbkb/index
# Error fetching https://athletics.cmu.edu/sports/mbkb/index: 403 Client Error: Forbidden for url: https://athletics.cmu.edu/sports/mbkb/index
# Fetching: https://athletics.cmu.edu/sports/mbkb/2024-25/schedule
# Error fetching https://athletics.cmu.edu/sports/mbkb/2024-25/schedule: 403 Client Error: Forbidden for url: https://athletics.cmu.edu/sports/mbkb/2024-25/schedule
# Fetching: https://x.com/tartanathletics?lang=en
# Fetching: https://trustarts.org/
# Error fetching https://trustarts.org/: 403 Client Error: Forbidden for url: https://trustarts.org/
# Fetching: https://trustarts.org/pct_home/blog
# Error fetching https://trustarts.org/pct_home/blog: 403 Client Error: Forbidden for url: https://trustarts.org/pct_home/blog
# Fetching: https://trustarts.org/pct_home/about
# Error fetching https://trustarts.org/pct_home/about: 403 Client Error: Forbidden for url: https://trustarts.org/pct_home/about
# Fetching: https://trustarts.org/pct_home/about/history
# Error fetching https://trustarts.org/pct_home/about/history: 403 Client Error: Forbidden for url: https://trustarts.org/pct_home/about/history
# Fetching: https://trustarts.org/pct_home/about/cultural-district
# Error fetching https://trustarts.org/pct_home/about/cultural-district: 403 Client Error: Forbidden for url: https://trustarts.org/pct_home/about/cultural-district
# Fetching: https://trustarts.org/pct_home/visual-arts
# Error fetching https://trustarts.org/pct_home/visual-arts: 403 Client Error: Forbidden for url: https://trustarts.org/pct_home/visual-arts
# Fetching: https://en.wikipedia.org/wiki/Pittsburgh_Cultural_Trust
# Fetching: https://carnegiemuseums.org/
# Error fetching https://carnegiemuseums.org/: 403 Client Error: Forbidden for url: https://carnegiemuseums.org/
# Fetching: https://carnegiemuseums.org/events/?start_date=2024-10-27&end_date=2025-11-29
# Error fetching https://carnegiemuseums.org/events/?start_date=2024-10-27&end_date=2025-11-29: 403 Client Error: Forbidden for url: https://carnegiemuseums.org/events/?start_date=2024-10-27&end_date=2025-11-29
# Fetching: https://en.wikipedia.org/wiki/Carnegie_Museums_of_Pittsburgh
# Fetching: https://en.wikipedia.org/wiki/Carnegie_Museum_of_Art
# Fetching: https://carnegiemuseums.org/about-us/our-history/
# Error fetching https://carnegiemuseums.org/about-us/our-history/: 403 Client Error: Forbidden for url: https://carnegiemuseums.org/about-us/our-history/
# Fetching: https://carnegiemnh.org/
# Error fetching https://carnegiemnh.org/: 403 Client Error: Forbidden for url: https://carnegiemnh.org/
# Fetching: https://carnegieart.org/
# Error fetching https://carnegieart.org/: 403 Client Error: Forbidden for url: https://carnegieart.org/
# Fetching: https://en.wikipedia.org/wiki/Carnegie_Museum_of_Natural_History
# Fetching: https://en.wikipedia.org/wiki/Heinz_History_Center
# Fetching: https://www.heinzhistorycenter.org/
# Error fetching https://www.heinzhistorycenter.org/: 403 Client Error: Forbidden for url: https://www.heinzhistorycenter.org/
# Fetching: https://www.thefrickpittsburgh.org/
# Fetching: https://en.wikipedia.org/wiki/The_Frick_Pittsburgh#:~:text=The%20Frick%20Pittsburgh%20is%20a,residence%20known%20as%20%22Clayton%22.
# Fetching: https://www.visitpittsburgh.com/events-festivals/food-festivals/
# Fetching: https://www.picklesburgh.com/
# Error fetching https://www.picklesburgh.com/: 403 Client Error: Forbidden for url: https://www.picklesburgh.com/
# Fetching: https://www.picklesburgh.com/vendors/
# Error fetching https://www.picklesburgh.com/vendors/: 403 Client Error: Forbidden for url: https://www.picklesburgh.com/vendors/
# Fetching: https://www.pghtacofest.com/about
# Fetching: https://pittsburghrestaurantweek.com/
# Fetching: https://pittsburghrestaurantweek.com/restaurants/summer-2024-restaurants/
# Fetching: https://littleitalydays.com/
# Error fetching https://littleitalydays.com/: 403 Client Error: Forbidden for url: https://littleitalydays.com/
# Fetching: https://littleitalydays.com/about-us/
# Error fetching https://littleitalydays.com/about-us/: 403 Client Error: Forbidden for url: https://littleitalydays.com/about-us/
# Fetching: https://bananasplitfest.com/
# Fetching: https://bananasplitfest.com/events/
# Error fetching https://bananasplitfest.com/events/: 403 Client Error: Forbidden for url: https://bananasplitfest.com/events/
# Fetching: https://en.wikipedia.org/wiki/Picklesburgh
# Saved content from URL https://en.wikipedia.org/wiki/Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/0.txt
# Saved content from URL https://en.wikipedia.org/wiki/History_of_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/1.txt
# Saved content from URL https://pittsburghpa.gov/pittsburgh/pgh-about to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/2.txt
# Saved content from URL https://www.britannica.com/technology/steel/Testing-of-properties to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/3.txt
# Saved content from URL https://pittsburghpa.gov/events/index.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/4.txt
# Saved content from URL https://www.visitpittsburgh.com/blog/move-in-day-pittsburgh-college-guide/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/5.txt
# Saved content from URL https://pittsburghpa.gov/mayor/pghmayors to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/6.txt
# Saved content from URL https://en.wikipedia.org/wiki/Economy_of_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/7.txt
# Saved content from URL https://en.wikipedia.org/wiki/Greater_Pittsburgh# to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/8.txt
# Saved content from URL https://en.wikipedia.org/wiki/Government_of_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/9.txt
# Saved content from URL https://en.wikipedia.org/wiki/Transportation_in_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/10.txt
# Saved content from URL https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/11.txt
# Saved content from URL https://en.wikipedia.org/wiki/Timeline_of_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/12.txt
# Saved content from URL https://en.wikipedia.org/wiki/List_of_people_from_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/13.txt
# Saved content from URL https://en.wikipedia.org/wiki/List_of_corporations_in_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/14.txt
# Saved content from URL https://pittsburghpa.gov/pittsburgh/pgh-sports to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/15.txt
# Saved content from URL https://pittsburghpa.gov/pittsburgh/cultural-activities to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/16.txt
# Saved content from URL https://www.cmu.edu/about/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/17.txt
# Saved content from URL https://www.cmu.edu/global/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/18.txt
# Saved content from URL https://en.wikipedia.org/wiki/Carnegie_Mellon_University to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/19.txt
# Saved content from URL https://www.cmu.edu/student-admission/index.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/20.txt
# Saved content from URL https://www.cmu.edu/admission/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/21.txt
# Saved content from URL https://www.cmu.edu/graduate/prospective/index.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/22.txt
# Saved content from URL https://www.cmu.edu/leadership/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/23.txt
# Saved content from URL https://www.cmu.edu/strategic-plan/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/24.txt
# Saved content from URL https://www.cmu.edu/strategic-plan/about/vision-mission.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/25.txt
# Saved content from URL https://www.cmu.edu/strategic-plan/about/values.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/26.txt
# Saved content from URL https://www.cmu.edu/diversity/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/27.txt
# Saved content from URL https://en.wikipedia.org/wiki/Carnegie_Mellon_University_traditions to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/28.txt
# Saved content from URL https://www.cmu.edu/about/rankings.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/29.txt
# Saved content from URL https://www.cmu.edu/about/awards.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/30.txt
# Saved content from URL https://www.cmu.edu/cfa/music/concerts-events/opera-events.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/31.txt
# Saved content from URL https://www.cmu.edu/cfa/music/concerts-events/index.html to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/32.txt
# Saved content from URL https://events.cmu.edu/all to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/33.txt
# Saved content from URL https://pittsburghmusicals.com/season/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/34.txt
# Saved content from URL https://www.chambermusicpittsburgh.org/2024-2025-mainstage-live/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/35.txt
# Saved content from URL https://makemusicpittsburgh.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/36.txt
# Saved content from URL https://en.wikipedia.org/wiki/Pittsburgh_Symphony_Orchestra to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/37.txt
# Saved content from URL https://www.pittsburghsymphony.org/feed?format=rss to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/38.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/about-landing/melia-p-tourangeau-president to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/39.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/biographies/pso-conductors/honeck-manfred to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/40.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/musicians to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/41.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/community-landing/learning-programs to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/42.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/subscriptions/why-subscribe-24-25/24-25-fiddlesticks-musical-exploration to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/43.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/community-landing/learning-programs/schooltime-concerts to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/44.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/community-landing/learning-programs/schooltime-concerts/digital-schooltime to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/45.txt
# Saved content from URL https://www.pittsburghsymphony.org/pso_home/web/give-landing/corporate-partnerships/dining-partners to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/46.txt
# Saved content from URL https://www.bandsintown.com/c/pittsburgh-pa?came_from=253&utm_medium=web&utm_source=city_page&utm_campaign=top_event&sort_by_filter=Number+of+RSVPs&concerts=true to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/47.txt
# Saved content from URL https://www.visitpittsburgh.com/blog/pittsburgh-music-venues/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/48.txt
# Saved content from URL https://en.wikipedia.org/wiki/Pittsburgh_Opera to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/49.txt
# Saved content from URL https://pittsburghopera.org/about to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/50.txt
# Saved content from URL https://pittsburghopera.org/about/mission-history to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/51.txt
# Saved content from URL https://pittsburghopera.org/resident-artists/2024-25resident-artists to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/52.txt
# Saved content from URL https://pittsburghopera.org/resident-artists/faculty-administration/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/53.txt
# Saved content from URL https://pittsburghopera.org/resident-artists/history-alumni/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/54.txt
# Saved content from URL https://pittsburghopera.org/our-team/board-of-directors to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/55.txt
# Saved content from URL https://pittsburghopera.org/our-team/staff to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/56.txt
# Saved content from URL https://pittsburghopera.org/our-team/orchestra to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/57.txt
# Saved content from URL https://pittsburghopera.org/our-team/chorus to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/58.txt
# Saved content from URL https://pittsburghopera.org/facilities/pittsburgh-opera-headquarters/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/59.txt
# Saved content from URL https://pittsburghopera.org/support/foundation-support to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/60.txt
# Saved content from URL https://pittsburghopera.org/support/government-support to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/61.txt
# Saved content from URL https://pittsburghopera.org/about/inclusion-diversity-equity-accessibility-idea/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/62.txt
# Saved content from URL https://pittsburghopera.org/education/mobile-app to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/63.txt
# Saved content from URL https://pittsburghopera.org/education/bravo-academy to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/64.txt
# Saved content from URL https://pittsburghopera.org/season to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/65.txt
# Saved content from URL https://pittsburghopera.org/season/tosca to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/66.txt
# Saved content from URL https://pittsburghopera.org/season/cavalleria-rusticana-pagliacci to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/67.txt
# Saved content from URL https://pittsburghopera.org/season/armida to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/68.txt
# Saved content from URL https://pittsburghopera.org/season/madama-butterfly to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/69.txt
# Saved content from URL https://pittsburghopera.org/season/woman-with-eyes-closed to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/70.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1727755200000&end=1730415540000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/71.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1730433600000&end=1733011140000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/72.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1733029200000&end=1735689540000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/73.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1735707600000&end=1738367940000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/74.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1738386000000&end=1740787140000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/75.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1740805200000&end=1743461940000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/76.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1743480000000&end=1746053940000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/77.txt
# Saved content from URL https://pittsburghopera.org/calendar?timequery=month&prev=-1&start=1746072000000&end=1748732340000&hsLang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/78.txt
# Saved content from URL https://pittsburghopera.org/season/special-events to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/79.txt
# Saved content from URL https://pittsburghopera.org/education/educators to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/80.txt
# Saved content from URL https://pittsburghopera.org/education/students to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/81.txt
# Saved content from URL https://www.pghcitypaper.com/pittsburgh/EventSearch?v=d to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/82.txt
# Saved content from URL https://downtownpittsburgh.com/events/?n=1&y=2025&cat=0 to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/83.txt
# Saved content from URL https://downtownpittsburgh.com/events/?n=12&y=2024&cat=0 to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/84.txt
# Saved content from URL https://downtownpittsburgh.com/events/?n=11&y=2024&cat=0 to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/85.txt
# Saved content from URL https://downtownpittsburgh.com/events/?n=10&y=2024&cat=0 to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/86.txt
# Saved content from URL https://pittsburgh.events/october/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/87.txt
# Saved content from URL https://pittsburgh.events/november/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/88.txt
# Saved content from URL https://pittsburgh.events/december/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/89.txt
# Saved content from URL https://pittsburgh.events/january/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/90.txt
# Saved content from URL https://pittsburgh.events/february/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/91.txt
# Saved content from URL https://pittsburgh.events/march/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/92.txt
# Saved content from URL https://pittsburgh.events/april/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/93.txt
# Saved content from URL https://pittsburgh.events/may/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/94.txt
# Saved content from URL https://pittsburgh.events/june/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/95.txt
# Saved content from URL https://pittsburgh.events/july/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/96.txt
# Saved content from URL https://pittsburgh.events/august/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/97.txt
# Saved content from URL https://pittsburgh.events/september/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/98.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/99.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/pittsburgh-steelers/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/100.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/pittsburgh-pirates/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/101.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/pittsburgh-penguins/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/102.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/college-sports/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/103.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/other-sports-teams/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/104.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/terrible-towel/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/105.txt
# Saved content from URL https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/pittsburgh-riverhounds/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/106.txt
# Saved content from URL https://www.visitpittsburgh.com/blog/steelers-hall-of-honor-museum/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/107.txt
# Saved content from URL https://www.visitpittsburgh.com/blog/guide-to-acrisure-stadium-for-steelers-fans/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/108.txt
# Saved content from URL https://www.visitpittsburgh.com/blog/what-to-eat-at-pnc-park/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/109.txt
# Saved content from URL https://www.visitpittsburgh.com/blog/ppg-paints-arena-penguins-guide/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/110.txt
# Saved content from URL https://www.steelers.com/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/111.txt
# Saved content from URL https://www.steelers.com/schedule/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/112.txt
# Saved content from URL https://en.wikipedia.org/wiki/Myron_Cope to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/113.txt
# Saved content from URL https://www.dkpittsburghsports.com/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/114.txt
# Saved content from URL https://en.wikipedia.org/wiki/Sports_in_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/115.txt
# Saved content from URL https://www.nytimes.com/athletic/location/pittsburgh/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/116.txt
# Saved content from URL https://athletics.cmu.edu/landing/index to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/117.txt
# Saved content from URL https://athletics.cmu.edu/sports/mbkb/index to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/118.txt
# Saved content from URL https://athletics.cmu.edu/sports/mbkb/2024-25/schedule to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/119.txt
# Saved content from URL https://x.com/tartanathletics?lang=en to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/120.txt
# Saved content from URL https://trustarts.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/121.txt
# Saved content from URL https://trustarts.org/pct_home/blog to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/122.txt
# Saved content from URL https://trustarts.org/pct_home/about to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/123.txt
# Saved content from URL https://trustarts.org/pct_home/about/history to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/124.txt
# Saved content from URL https://trustarts.org/pct_home/about/cultural-district to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/125.txt
# Saved content from URL https://trustarts.org/pct_home/visual-arts to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/126.txt
# Saved content from URL https://en.wikipedia.org/wiki/Pittsburgh_Cultural_Trust to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/127.txt
# Saved content from URL https://carnegiemuseums.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/128.txt
# Saved content from URL https://carnegiemuseums.org/events/?start_date=2024-10-27&end_date=2025-11-29 to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/129.txt
# Saved content from URL https://en.wikipedia.org/wiki/Carnegie_Museums_of_Pittsburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/130.txt
# Saved content from URL https://en.wikipedia.org/wiki/Carnegie_Museum_of_Art to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/131.txt
# Saved content from URL https://carnegiemuseums.org/about-us/our-history/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/132.txt
# Saved content from URL https://carnegiemnh.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/133.txt
# Saved content from URL https://carnegieart.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/134.txt
# Saved content from URL https://en.wikipedia.org/wiki/Carnegie_Museum_of_Natural_History to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/135.txt
# Saved content from URL https://en.wikipedia.org/wiki/Heinz_History_Center to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/136.txt
# Saved content from URL https://www.heinzhistorycenter.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/137.txt
# Saved content from URL https://www.thefrickpittsburgh.org/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/138.txt
# Saved content from URL https://en.wikipedia.org/wiki/The_Frick_Pittsburgh#:~:text=The%20Frick%20Pittsburgh%20is%20a,residence%20known%20as%20%22Clayton%22. to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/139.txt
# Saved content from URL https://www.visitpittsburgh.com/events-festivals/food-festivals/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/140.txt
# Saved content from URL https://www.picklesburgh.com/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/141.txt
# Saved content from URL https://www.picklesburgh.com/vendors/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/142.txt
# Saved content from URL https://www.pghtacofest.com/about to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/143.txt
# Saved content from URL https://pittsburghrestaurantweek.com/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/144.txt
# Saved content from URL https://pittsburghrestaurantweek.com/restaurants/summer-2024-restaurants/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/145.txt
# Saved content from URL https://littleitalydays.com/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/146.txt
# Saved content from URL https://littleitalydays.com/about-us/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/147.txt
# Saved content from URL https://bananasplitfest.com/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/148.txt
# Saved content from URL https://bananasplitfest.com/events/ to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/149.txt
# Saved content from URL https://en.wikipedia.org/wiki/Picklesburgh to /Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/150.txt
# Crawling complete!

# %%
pip install selenium beautifulsoup4 webdriver-manager
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.8/site-packages (4.9.3)
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.8/site-packages (from selenium) (1.26.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4) (2.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from webdriver-manager) (2.25.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.8/site-packages (from webdriver-manager) (20.4)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.8/site-packages (from webdriver-manager) (1.0.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from packaging->webdriver-manager) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging->webdriver-manager) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver-manager) (2.10)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2
# WARNING: You are using pip version 21.1.3; however, version 24.2 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from tqdm import tqdm

# Function to fetch the page content using Selenium
def fetch_page_text_selenium(url):
    try:
        driver = webdriver.Chrome(driverPath) 
        # Initialize Chrome WebDriver
        driver.get(url)
        
        # Wait for the page to load (adjust time if needed)
        time.sleep(3)
        
        # Get page source and close the browser
        page_source = driver.page_source
        driver.quit()

        # Parse the page content using BeautifulSoup
        soup = BeautifulSoup(page_source, 'html.parser')

        # Extract and clean the text from the page
        page_text = soup.get_text(separator='\n', strip=True)
        return page_text

    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None

# Function to read URLs from CSV and crawl each one
def crawl_urls_from_csv(csv_file_path, url_column_name):
    with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for index, row in enumerate(reader):
            url = row[url_column_name]
            print(f"Fetching: {url}")
            text = fetch_page_text_selenium(url)
            if text:
                # Save the crawled text to a file with the index as the filename
                output_file = f"/Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/crawled/crawled_text_data/{index}.txt"
                with open(output_file, 'w', encoding='utf-8') as f:
                    f.write(text)
                print(f"Saved content to {output_file}")

if __name__ == "__main__":
    csv_file_path = '/Users/alan/11711/nlp-from-scratch-assignment/data/1010_160_entries/raw/raw_csv_data/data_source.csv'
    url_column_name = 'Source URL'
    driverPath = '/Users/alan/Downloads/chromedriver-mac-arm64/chromedriver'


    # Start crawling the URLs from the CSV
    crawl_urls_from_csv(csv_file_path, url_column_name)
# Out:
# Fetching: https://en.wikipedia.org/wiki/Pittsburgh
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3ccd5c0d53f5> in <module>
#      55
#      56     # Start crawling the URLs from the CSV
# ---> 57     crawl_urls_from_csv(csv_file_path, url_column_name)
#
# <ipython-input-2-3ccd5c0d53f5> in crawl_urls_from_csv(csv_file_path, url_column_name)
#      40             url = row[url_column_name]
#      41             print(f"Fetching: {url}")
# ---> 42             text = fetch_page_text_selenium(url)
#      43             if text:
#      44                 # Save the crawled text to a file with the index as the filename
#
# <ipython-input-2-3ccd5c0d53f5> in fetch_page_text_selenium(url)
#      16
#      17         # Wait for the page to load (adjust time if needed)
# ---> 18         time.sleep(3)
#      19
#      20         # Get page source and close the browser
#
# KeyboardInterrupt:
