# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample CSV data
data = pd.read_csv('../data/raw/raw_csv_data/data_source.csv')

# Load the DataFrame
df = pd.DataFrame(data)

# Split the 'Tags' column by commas (if any) and explode it into individual rows
df['Tags'] = df['Tags'].str.split(',')
df = df.explode('Tags')

# Trim whitespace (if there are any spaces around the tags)
df['Tags'] = df['Tags'].str.strip()

# Count the occurrences of each tag
tag_counts = df['Tags'].value_counts()

# Plot the bar chart
plt.figure(figsize=(10, 6))
tag_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Tags')
plt.xlabel('Tags')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
output_svg_file = 'tag_frequency_plot.pdf'
plt.savefig(output_svg_file, format='pdf', bbox_inches='tight')
plt.show()
